# %% [markdown]
# ![title](C:/Users/SAHIL JOSAN/Desktop/141241.png)

# %%
from IPython.display import Image
Image(filename="C:/Users/SAHIL JOSAN/Desktop/1241.JPG", width = 1000, height=1000)

# %% [markdown]
# <img src="‪C:/Users/SAHIL JOSAN/Desktop/141241.png",width=200,height=200>

# %%
# %%html
# <img src="‪C:/Users/SAHIL JOSAN/Desktop/141241.png",width=500,height=300>
# Out:
# <img src="‪C:/Users/SAHIL JOSAN/Desktop/141241.png",width=500,height=300>
